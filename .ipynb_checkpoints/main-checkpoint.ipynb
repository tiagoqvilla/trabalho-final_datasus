# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sinan_tuberculose.csv', sep=';')
df.head()
# Out:
#   data_extracao             identificador_pessoa2 data_diagnostico  \
# 0    2024-06-11  05ff7d8b4440fa151bf3975e7e098278          06/2021
# 1    2024-06-11  fab44173a164545bfd2e08eb9d36f02d          01/2020
# 2    2024-06-11  4bb895abdc6903e107ac45a9a4e4a676          05/2021
# 3    2024-06-11  a6af85b1c46c79fefcc3db445d9b8060          03/2018
# 4    2024-06-11  8c8dccd6f96aa3a2c0dd6524c8fe668e          03/2020
#
#   data_notificacao data_nascimento    raca       sexo     forma  \
# 0          06/2021         11/1992   PARDA  MASCULINO  PULMONAR
# 1          01/2020         10/1955  BRANCA   FEMININO  PULMONAR
# 2          06/2021         06/1969   PRETA  MASCULINO  PULMONAR
# 3          03/2018         05/1982   PRETA   FEMININO  PULMONAR
# 4          03/2020         05/1979  BRANCA  MASCULINO  PULMONAR
#
#          cultura baciloscopia_escarro             teste_molecular_rapido  \
# 0  NÃO REALIZADA        NÃO REALIZADA                      NÃO REALIZADO
# 1       POSITIVA             NEGATIVA                     NÃO DETECTÁVEL
# 2  NÃO REALIZADA        NÃO REALIZADA                      NÃO REALIZADO
# 3  NÃO REALIZADA             POSITIVA  DETECTÁVEL SENSÍVEL À RIFAMPICINA
# 4       POSITIVA             POSITIVA  DETECTÁVEL SENSÍVEL À RIFAMPICINA
#
#   teste_sensibilidade agravos_aids agravos_alcool agravos_diabetes  \
# 0                 NaN          NÃO            SIM              NÃO
# 1            SENSÍVEL          NÃO            SIM              NÃO
# 2                 NaN          SIM            SIM              NÃO
# 3                 NaN          SIM            SIM              NÃO
# 4            SENSÍVEL          NÃO            SIM              NÃO
#
#   agravos_tabagismo
# 0               SIM
# 1               SIM
# 2               NÃO
# 3               SIM
# 4               SIM

# %%
# Remove colunas irrelevantes
df.drop(columns=['identificador_pessoa2', 'data_extracao','teste_molecular_rapido', 'teste_sensibilidade', 'baciloscopia_escarro','cultura'], inplace=True)

df['data_diagnostico'] = pd.to_datetime(df['data_diagnostico'], format='%m/%Y')
df['data_nascimento'] = pd.to_datetime(df['data_nascimento'], format='%m/%Y')
df['idade'] = df['data_diagnostico'].dt.year - df['data_nascimento'].dt.year - ((df['data_diagnostico'].dt.month < df['data_nascimento'].dt.month) | ((df['data_diagnostico'].dt.month == df['data_nascimento'].dt.month) & (df['data_diagnostico'].dt.day < df['data_nascimento'].dt.day)))

df
# Out:
#       data_diagnostico data_notificacao data_nascimento    raca       sexo  \
# 0           2021-06-01          06/2021      1992-11-01   PARDA  MASCULINO
# 1           2020-01-01          01/2020      1955-10-01  BRANCA   FEMININO
# 2           2021-05-01          06/2021      1969-06-01   PRETA  MASCULINO
# 3           2018-03-01          03/2018      1982-05-01   PRETA   FEMININO
# 4           2020-03-01          03/2020      1979-05-01  BRANCA  MASCULINO
# ...                ...              ...             ...     ...        ...
# 40249       2019-02-01          02/2019      1972-05-01  BRANCA  MASCULINO
# 40250       2020-04-01          04/2020      1986-04-01  BRANCA  MASCULINO
# 40251       2017-08-01          12/2017      1984-12-01  BRANCA  MASCULINO
# 40252       2020-04-01          04/2020      1994-01-01  BRANCA   FEMININO
# 40253       2020-05-01          06/2020      1957-11-01   PARDA  MASCULINO
#
#                           forma agravos_aids agravos_alcool agravos_diabetes  \
# 0                      PULMONAR          NÃO            SIM              NÃO
# 1                      PULMONAR          NÃO            SIM              NÃO
# 2                      PULMONAR          SIM            SIM              NÃO
# 3                      PULMONAR          SIM            SIM              NÃO
# 4                      PULMONAR          NÃO            SIM              NÃO
# ...                         ...          ...            ...              ...
# 40249                  PULMONAR          NÃO            NÃO              NÃO
# 40250  PULMONAR + EXTRAPULMONAR          NÃO            SIM              NÃO
# 40251                  PULMONAR          NÃO            NÃO              NÃO
# 40252                  PULMONAR          NÃO            NÃO              NÃO
# 40253                  PULMONAR          NÃO            NÃO              SIM
#
#       agravos_tabagismo  idade
# 0                   SIM   28.0
# 1                   SIM   64.0
# 2                   NÃO   51.0
# 3                   SIM   35.0
# 4                   SIM   40.0
# ...                 ...    ...
# 40249               NaN   46.0
# 40250               SIM   34.0
# 40251               NÃO   32.0
# 40252               NÃO   26.0
# 40253               NÃO   62.0
#
# [40254 rows x 11 columns]

# %%
df.replace({'SIM': 1, 'NÃO': 0, 'IGNORADO': 0}, inplace=True)
df.fillna(0, inplace=True)
df
# Out:
# /tmp/ipykernel_68881/3672950089.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'SIM': 1, 'NÃO': 0, 'IGNORADO': 0}, inplace=True)
# /tmp/ipykernel_68881/3672950089.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.fillna(0, inplace=True)
#       data_diagnostico data_notificacao      data_nascimento    raca  \
# 0           2021-06-01          06/2021  1992-11-01 00:00:00   PARDA
# 1           2020-01-01          01/2020  1955-10-01 00:00:00  BRANCA
# 2           2021-05-01          06/2021  1969-06-01 00:00:00   PRETA
# 3           2018-03-01          03/2018  1982-05-01 00:00:00   PRETA
# 4           2020-03-01          03/2020  1979-05-01 00:00:00  BRANCA
# ...                ...              ...                  ...     ...
# 40249       2019-02-01          02/2019  1972-05-01 00:00:00  BRANCA
# 40250       2020-04-01          04/2020  1986-04-01 00:00:00  BRANCA
# 40251       2017-08-01          12/2017  1984-12-01 00:00:00  BRANCA
# 40252       2020-04-01          04/2020  1994-01-01 00:00:00  BRANCA
# 40253       2020-05-01          06/2020  1957-11-01 00:00:00   PARDA
#
#             sexo                     forma  agravos_aids  agravos_alcool  \
# 0      MASCULINO                  PULMONAR           0.0             1.0
# 1       FEMININO                  PULMONAR           0.0             1.0
# 2      MASCULINO                  PULMONAR           1.0             1.0
# 3       FEMININO                  PULMONAR           1.0             1.0
# 4      MASCULINO                  PULMONAR           0.0             1.0
# ...          ...                       ...           ...             ...
# 40249  MASCULINO                  PULMONAR           0.0             0.0
# 40250  MASCULINO  PULMONAR + EXTRAPULMONAR           0.0             1.0
# 40251  MASCULINO                  PULMONAR           0.0             0.0
# 40252   FEMININO                  PULMONAR           0.0             0.0
# 40253  MASCULINO                  PULMONAR           0.0             0.0
#
#        agravos_diabetes  agravos_tabagismo  idade
# 0                   0.0                1.0   28.0
# 1                   0.0                1.0   64.0
# 2                   0.0                0.0   51.0
# 3                   0.0                1.0   35.0
# 4                   0.0                1.0   40.0
# ...                 ...                ...    ...
# 40249               0.0                0.0   46.0
# 40250               0.0                1.0   34.0
# 40251               0.0                0.0   32.0
# 40252               0.0                0.0   26.0
# 40253               1.0                0.0   62.0
#
# [40254 rows x 11 columns]

# %%
df.to_csv('processed_sinan.csv', sep=';', index=False)

# %%
from scipy.stats import chi2_contingency#teste quiquadrado para correlacao
#h0,Sob H0:Oij=Eij para todas as células, no caso correlacao = 0
#h1, correlacao !=0
def test_1(df, column):
    contingency_table = pd.crosstab(df['forma'], df[column])
    res= chi2_contingency(contingency_table)
    return res


results = {}
columns = ['agravos_aids', 'agravos_alcool', 'agravos_diabetes', 'agravos_tabagismo']

for column in columns:
    res = test_1(df, column)
    results[column] = {
        'X^2': res.statistic,
        'p_value': res.pvalue,
    }

results
#em todos os casos p-value < 0.05, rejeita-se h0
# Out:
# {'agravos_aids': {'X^2': 2626.9470963043036, 'p_value': 0.0},
#  'agravos_alcool': {'X^2': 376.48518078121407,
#   'p_value': 1.7671838510130775e-82},
#  'agravos_diabetes': {'X^2': 35.86847007122927,
#   'p_value': 1.6265247903365293e-08},
#  'agravos_tabagismo': {'X^2': 345.2605864503795,
#   'p_value': 1.065654057724334e-75}}

# %%
#testando todos os agarvos juntos
contingency_table = pd.crosstab(df['forma'], [df['agravos_aids'], df['agravos_alcool'], df['agravos_diabetes'], df['agravos_tabagismo']])

res = chi2_contingency(contingency_table)

print(res.statistic)
print(res.pvalue)
# Out:
# 3415.190500198677
# 0.0

# %%
total = len(df)
pulmonar = len(df[df['forma'] == 'PULMONAR'])
extrapulmonar = len(df[df['forma'] == 'EXTRAPULMONAR'])
both_cases = len(df[df['forma'] == 'PULMONAR + EXTRAPULMONAR'])

# Pirori
P_Pulmonar = (pulmonar + both_cases) / total
P_Extrapulmonar = (extrapulmonar + both_cases) / total

# Verossimilhanca
P_Extrapulmonar_given_Pulmonar = both_cases / (pulmonar+ both_cases)
P_Pulmonar_given_Extrapulmonar = both_cases / (extrapulmonar + both_cases)

# Teorema de bayes
Posteriori_1 = (P_Extrapulmonar_given_Pulmonar * P_Pulmonar) / P_Extrapulmonar
Posteriori_2 = (P_Pulmonar_given_Extrapulmonar * P_Extrapulmonar) / P_Pulmonar

print("Probabilidade de ter pulmonar dado que tem extrapulmonar: ",Posteriori_1)
print("Probabilidade de ter extrapulmonar dado que tem pulmonar: ",Posteriori_2)
# Out:
# Probabilidade de ter pulmonar dado que tem extrapulmonar:  0.3520156314273961
# Probabilidade de ter extrapulmonar dado que tem pulmonar:  0.10081583365240185

# %%
pulmonar_tb = df[df['forma'].str.contains(r'\bPULMONAR\b', regex=True)]

agravos = ['agravos_aids', 'agravos_alcool', 'agravos_diabetes', 'agravos_tabagismo']
probabilities = {}

for agravo in agravos:
    extrapulmonar_with_agravo = pulmonar_tb[pulmonar_tb[agravo] == 1]['forma'].str.contains('EXTRAPULMONAR').sum()
    total_with_agravo = pulmonar_tb[pulmonar_tb[agravo] == 1].shape[0]
    probability = extrapulmonar_with_agravo / total_with_agravo if total_with_agravo != 0 else 0
    probabilities[agravo] = probability



probabilities
# Out:
# {'agravos_aids': 0.23471130850700375,
#  'agravos_alcool': 0.11421664904064058,
#  'agravos_diabetes': 0.0672,
#  'agravos_tabagismo': 0.08686702346644709}

# %%
extrapulmonar_tb = df[df['forma'].str.contains('EXTRAPULMONAR', regex=True)]

agravos = ['agravos_aids', 'agravos_alcool', 'agravos_diabetes', 'agravos_tabagismo']
probabilities = {}

for agravo in agravos:
    pulmonar_with_agravo = extrapulmonar_tb[extrapulmonar_tb[agravo] == 1]['forma'].str.contains(r'\bPULMONAR\b', regex=True).sum()
    total_with_agravo = extrapulmonar_tb[extrapulmonar_tb[agravo] == 1].shape[0]
    probability = pulmonar_with_agravo / total_with_agravo if total_with_agravo != 0 else 0
    probabilities[agravo] = probability

probabilities
# Out:
# {'agravos_aids': 0.46293800539083557,
#  'agravos_alcool': 0.5575221238938053,
#  'agravos_diabetes': 0.30656934306569344,
#  'agravos_tabagismo': 0.5314861460957179}

# %%
df['EXTRAPULMONAR'] = df['forma'].str.contains('EXTRAPULMONAR', regex=True).astype(int)
df['PULMONAR'] = df['forma'].str.contains(r'\bPULMONAR\b', regex=True).astype(int)

correlation_matrix = df[['EXTRAPULMONAR', 'PULMONAR'] + agravos].corr()
correlation_matrix
# Out:
#                    EXTRAPULMONAR  PULMONAR  agravos_aids  agravos_alcool  \
# EXTRAPULMONAR           1.000000 -0.763320      0.227239       -0.058678
# PULMONAR               -0.763320  1.000000     -0.098058        0.094452
# agravos_aids            0.227239 -0.098058      1.000000        0.068757
# agravos_alcool         -0.058678  0.094452      0.068757        1.000000
# agravos_diabetes       -0.028533  0.016112     -0.081608        0.003343
# agravos_tabagismo      -0.081026  0.090825      0.050901        0.220923
#
#                    agravos_diabetes  agravos_tabagismo
# EXTRAPULMONAR             -0.028533          -0.081026
# PULMONAR                   0.016112           0.090825
# agravos_aids              -0.081608           0.050901
# agravos_alcool             0.003343           0.220923
# agravos_diabetes           1.000000           0.027661
# agravos_tabagismo          0.027661           1.000000

# %%
correlation_matrix.to_csv('correlation_matrix.csv', sep=';')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
f,ax = plt.subplots(figsize=(14, 10))
sns.heatmap(correlation_matrix.corr(), annot=True, fmt = ".1f",ax=ax)
# Out:
# <Axes: >

# %%
plt.savefig('matrix.png')
plt.close()
